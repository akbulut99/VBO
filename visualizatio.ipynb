# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
a = np.random.randint(1,10,6)
a.reshape(2,3)
plt.plot(a)
plt.ylabel("y ekseni")
plt.xlabel("X ekseni")
plt.show()

# %%
df =pd.DataFrame({'Türkiye':[1980,1987,1999,2003,2007,2013,2018,2023],'Almanya':[1978,1982,1997,2001,2003,2012,2017,2021]})
df.plot(kind="density")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# !pip3 install folium==0.5.0
# Out:
# ...
#   Created wheel for folium: filename=folium-0.5.0-py3-none-any.whl size=76146 sha256=ba273872ec4dc6a42331a706f5dba6b53c82f3aa49f092c0ef2f4b28e2d646b2
#   Stored in directory: c:\users\akbul\appdata\local\pip\cache\wheels\73\dc\aa\47aee8bdcbe7ff36e915e172ffa1e75249e82a0e675ddc1668
# Successfully built folium
# ...

# %%
import folium as fl

# %%
w_map= fl.Map(location=[39,45], zoom_start=4)
w_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
